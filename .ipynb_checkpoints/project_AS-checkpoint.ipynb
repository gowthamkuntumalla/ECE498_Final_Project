# %%
import numpy as np
import pandas as pd
import math as mth
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import time

# %%
# sandp500 = pd.read_csv ('sandp500/all_stocks_5yr.csv')
# sandp500['date'] = pd.to_datetime(sandp500['date'])

# %%
#Function that returns specific time-range stockvalues for a particular company
def period(df, initial, final):
    df = df.set_index(['date'])
    return df.loc[initial:final].reset_index()

# %% [markdown]
# # (1) AD Analysis

# %%
# https://www.investopedia.com/terms/a/accumulationdistribution.asp
# A/D=Previous A/D+CMFV where CMFV = ((c - l) - (h - c))/(h - l)

def AD (p):
 
    for x in all_companies:
        temp = sp500.loc[x]
        c = np.empty((p-1,))
        c[:] = np.NaN
        c = list(c)
        c.extend(temp['close'].iloc[p-1:])
   
        v = temp['volume'].rolling(window = p).sum()
        h = temp['high'].rolling(window = p).max()
        l = temp['low'].rolling(window = p).min()
        
        AD = v * (((c - l) - (h - c))/(h - l))
        output = AD.cumsum()
        sp500.loc[x,'Accum_Distri'] = pd.DataFrame(output)

# %% [markdown]
# # (2) GOPALAKRISHNAN RANGE INDEX (GAPO Index)

# %%
# Standard code for working on specific time-range stockvalues for a particular company
def GAPO (p):
#     initial = company['date'][0]
#     final = initial + pd.Timedelta(p, unit='d')
#     output = []
#     last_elem = company['date'].iloc[-1]

#     while final <= last_elem:
#         temp = period(company, initial, final) #A pandas frame with only the stocks in the particular time range
#   initial += pd.Timedelta(1, unit='d')
#         final += pd.Timedelta(1, unit='d')
        
    for x in all_companies:
        temp = sp500.loc[x]
        
        hh = temp['high'].rolling(window = p).max()
        ll = temp['low'].rolling(window = p).min()
        
        GAPO = np.log(hh-ll)/np.log(p)
        sp500.loc[x,'GAPO'] = pd.DataFrame(GAPO)

# %% [markdown]
# # (3) LINEAR REGRESSION FORECAST (LRF)

# %%
# Standard code for working on specific time-range stockvalues for a particular company
def LRF (company, p):
    initial = company['date'][0]
    final = initial + pd.Timedelta(p, unit='d')
    output = [[],[],[]]
    last_elem = company['date'].iloc[-1]

    while final <= last_elem:
        temp = period(company, initial, final) #A pandas frame with only the stocks in the particular time range
        
        temp['average'] = temp.apply(lambda row: (row.high + row.low)/2. , axis = 1)         
        x = np.array(temp.apply(lambda row: row.date.value/10**9/86400, axis = 1))
        output[0].extend(x)
        output[1].extend(temp['average'])
        
        answer = LinearRegression().fit(x.reshape(-1, 1), np.array(temp['average']).reshape(-1, 1),)
        output[2].extend(answer.coef_[0][0]*x + answer.intercept_[0])       

        initial = final + pd.Timedelta(1, unit='d')
        final = initial + pd.Timedelta(p, unit='d')

    return output

# %% [markdown]
# # (4) On Balance Volume (OBV)

# %%
# Standard code for working on specific time-range stockvalues for a particular company
def OBV (p):

    for x in all_companies:   
        temp = sp500.loc[x]
        v = temp['volume'].rolling(window = p).sum()
        c = np.empty((p-1,))
        c[:] = np.NaN
        c = list(c)
        c.extend(temp['close'].iloc[p-1:])
        
        for i in range(p, len(c)):
            if c[i] < c[i-1]:
                v[i] = - v[i]
            if c[i] == c[i-1]:
                v[i] = 0
            
        obv = np.cumsum(v)
        sp500.loc[x,'On_Bal_Vol'] = pd.DataFrame(obv)

# %% [markdown]
# # (5) Relative Strength Index (RSI)

# %%
# Standard code for working on specific time-range stockvalues for a particular company
def RSI (p):
    for x in all_companies:
        temp = sp500.loc[x]
        
        difference = temp['close'].diff()
        up, down = difference.copy(), difference.copy()
        up [up < 0] = 0
        down [down > 0] = 0
        rs = up.rolling(window = p).mean() / down.abs().rolling(window = p).mean()
        rsi = 100.0 - (100.0 / (1.0 + rs))
        sp500.loc[x,'RSI'] = pd.DataFrame(rsi)

# %% [markdown]
# # (6) Weighted Close (WC)

# %%
# Note there is no time granularity for WC analysis
def WC(p):        
    for x in all_companies:
        temp = sp500.loc[x]
        output = (temp['high'] + temp['low'] + 2*temp['close'])/4
        sp500.loc[x,'Weighted_Close'] = pd.DataFrame(output)

# %% [markdown]
# # (7) Williams %R Formula (WRF)

# %%
def WRF (p):
    for x in all_companies:
        temp = sp500.loc[x]

        hh = temp['high'].rolling(window = p).max()
        ll = temp['low'].rolling(window = p).min()
        close = np.empty((p-1,))
        close[:] = np.NaN
        close = list(close)
        close.extend(temp['close'].iloc[p-1:])
        
        WR = (hh-close)/(hh-ll)*(-100)
        sp500.loc[x,'Will_R_Form'] = pd.DataFrame(WR)

# %% [markdown]
# # (8) Aaron Oscillator (AO)

# %%
def AO (p):
    for x in all_companies:
        stocks = sp500.loc[x]
        output = np.empty((p-1,))
        output[:] = np.NaN
        output = list(output)
        first_run = True
        ctr1 = 0
        ctr2 = 0
        hh = 0
        ll = 0
        itr = p

        while itr <= len(stocks): 
            temp = stocks.iloc[itr - p: itr]
            if first_run or ctr1 == 25:
                hh = temp['high'].max()
                ctr1 = p - temp['high'].values.argmax() - 2

            if first_run or ctr2 == 25:
                ll = temp['low'].min()
                ctr2 = p - temp['low'].values.argmin() - 2
                
            if temp['high'].iloc[-1] >= hh:
                ctr1 = 0
                hh = temp['high'].iloc[-1]
            else: 
                ctr1 += 1

            if temp['low'].iloc[-1] <= ll:
                ctr2 = 0
                ll = temp['low'].iloc[-1]
            else: 
                ctr2 += 1
            
            a_up = 100*(p-ctr1)/p
            a_down = 100*(p-ctr2)/p
            a_osc = a_up - a_down   
            output.append(a_osc)
            itr += 1
            first_run = False
        
        sp500.loc[x,'Aaron_Osc'] = pd.DataFrame(output)

# %% [markdown]
# # (9) Donchian Width

# %%
def DW (p):    
    for x in all_companies:
        temp = sp500.loc[x]

        hh = temp['high'].rolling(window = p).max()
        ll = temp['low'].rolling(window = p).min()

        DW = hh - ll
        sp500.loc[x,'Donchian_Width'] = pd.DataFrame(DW)

# %% [markdown]
# # (10) True Range

# %%
def TR (p):    
    for x in all_companies:
        temp = sp500.loc[x]
        TR = temp['high'] - temp['low']
        
        sp500.loc[x,'True_Range'] = pd.DataFrame(TR)

# %% [markdown]
# # "MAIN FUNCTION"

# %%
# sp500 = sandp500.copy()
# sp500.set_index(['Name','date'], inplace=True)
# all_companies = sp500.index.get_level_values(0).unique() # gets the name of all companies

# p = 14 # Time period in days

# all_features = [AD,WRF,WC,GAPO,OBV,RSI,DW,TR,AO]

# for feature in all_features:
#     tic = time.perf_counter()
#     if feature == AO:
#         AO(25)
#     else:
#         feature(p)
    
#     toc = time.perf_counter()
#     print("{0} Done!".format(str(feature)))
#     print("Execution time: {0} seconds\n".format(toc - tic))

# %%
#sp500.to_csv('Akhilesh_Feature_Generation.csv')

# %% [markdown]
# # WARNING: RUN ALL BELOW ONLY AFTER GENERATING THE ALL_FEATURES_DF.CSV FILE

# %%
all_features = pd.read_csv('All_features_df.csv')
all_features['date'] = pd.to_datetime(all_features['date'])

# %%
all_features.head(3)
# Out:
#   Name       date   open   high    low  close   volume  bollinger_bandwidth  \
# 0  AAL 2013-02-08  15.07  15.12  14.63  14.75  8407500                  NaN
# 1  AAL 2013-02-11  14.89  15.01  14.26  14.46  8882000                  NaN
# 2  AAL 2013-02-12  14.45  14.51  14.10  14.27  8126000                  NaN
#
#    coppock_curve     macd  ...  typical_price  Accum_Distri  Will_R_Form  \
# 0            NaN  0.00000  ...      14.833333           NaN          NaN
# 1            NaN -0.00289  ...      14.576667           NaN          NaN
# 2            NaN -0.00624  ...      14.293333           NaN          NaN
#
#    Weighted_Close  GAPO  On_Bal_Vol  RSI  Donchian_Width  True_Range  \
# 0         14.8125   NaN         NaN  NaN             NaN        0.49
# 1         14.5475   NaN         NaN  NaN             NaN        0.75
# 2         14.2875   NaN         NaN  NaN             NaN        0.41
#
#    Aaron_Osc
# 0        NaN
# 1        NaN
# 2        NaN
#
# [3 rows x 27 columns]

# %% [markdown]
# ### Linear Regression Plot

# %%
# plt.subplots(figsize = (10,5))
# p = 14
# output = LRF(company, p)
# plt.plot(output[0], output[1], label='High-Low Average')
# plt.plot(output[0], output[2], label='Linear Regression Fit')
# plt.xlabel('Time in Days', size = 20)
# plt.ylabel('Price (in USD)', size = 20)
# plt.title('Stocks for {0}'.format(company['Name'].iloc[0]), size =30)
# plt.legend()
# plt.show()

# %% [markdown]
# # Condensing Time-Series Data to one number for PCA

# %%
my_df = all_features[['Name','date','bollinger_bandwidth','momentum_indic','pvi','rvi','st_dev','smi','stochastics','Will_R_Form','RSI','Aaron_Osc']]

# %%
my_df = my_df.dropna()
my_df.set_index(['Name','date'], inplace = True)

# %% [markdown]
# # (i) Trying out PCA on year-wise data
# # --> Creating a mean_year_df with year-wise estimation of mean for various features

# %%
all_years = ['201' + str(i) for i in range(3,9)]    
mean_list = [[] for _ in range(len(all_years))]
mean_year_df = [[] for _ in range(len(all_years))]

ctr = 0
for current_year in all_years:
    print("year: " +str(current_year) + " began")
    for company in my_df.index.get_level_values(0).unique():
        if len(my_df.loc[[company]]) < 1000:
            continue
        company_df = my_df.loc[company][current_year]
        mean_table = company_df.mean()
        d = {'Name': company}
        name_columns = ['bollinger_bandwidth','momentum_indic','pvi','rvi','st_dev','smi','stochastics','Will_R_Form','RSI','Aaron_Osc']
        for i in range(len(name_columns)):
            d[name_columns[i]] = mean_table.loc[name_columns[i]]

        mean_list[ctr].append(d)
    
    mean_year_df[ctr] = pd.DataFrame(mean_list[ctr])
    mean_year_df[ctr].set_index('Name', inplace = True)
    
    ctr += 1 # Update counter after inner loop ends
# Out:
# year: 2013 began
# year: 2014 began
# year: 2015 began
# year: 2016 began
# year: 2017 began
# year: 2018 began

# %% [markdown]
# # --> Creating a median_year_df with year-wise estimation of median for various features

# %%
all_years = ['201' + str(i) for i in range(3,9)]    
median_list = [[] for _ in range(len(all_years))]
median_year_df = [[] for _ in range(len(all_years))]

ctr = 0
for current_year in all_years:
    print("year: " +str(current_year) + " began")
    for company in my_df.index.get_level_values(0).unique():
        if len(my_df.loc[[company]]) < 1000:
            continue
        company_df = my_df.loc[company][current_year]
        median_table = company_df.median()
        d = {'Name': company}
        name_columns = ['bollinger_bandwidth','momentum_indic','pvi','rvi','st_dev','smi','stochastics','Will_R_Form','RSI','Aaron_Osc']
        for i in range(len(name_columns)):
            d[name_columns[i]] = median_table.loc[name_columns[i]]

        median_list[ctr].append(d)
    
    median_year_df[ctr] = pd.DataFrame(median_list[ctr])
    median_year_df[ctr].set_index('Name', inplace = True)
    
    ctr += 1 # Update counter after inner loop ends
# Out:
# year: 2013 began
# year: 2014 began
# year: 2015 began
# year: 2016 began
# year: 2017 began
# year: 2018 began

# %% [markdown]
# # (ii) Trying out PCA with even finer time-granularity (100 data points)
# # --> Creating a mean_100_df with mean for various features

# %%
len_max = 1235 # Since the max. number of rows for any company is 1235
mean_list = [[]]
mean_100_df = [[]]
ctr = 0
j = 0

while j < 1235:
    print("j value is: ", j)
    for company in my_df.index.get_level_values(0).unique():
        if len(my_df.loc[[company]]) < 1000:
            continue
            
        company_df = my_df.loc[company].iloc[j:j+100]
        mean_table = company_df.mean()
        d = {'Name': company}
        name_columns = ['bollinger_bandwidth','momentum_indic','pvi','rvi','st_dev','smi','stochastics','Will_R_Form','RSI','Aaron_Osc']
        for i in range(len(name_columns)):
            d[name_columns[i]] = mean_table.loc[name_columns[i]]

        mean_list[ctr].append(d)
    
    mean_100_df[ctr] = pd.DataFrame(mean_list[ctr])
    mean_100_df[ctr].set_index('Name', inplace = True)
    
    mean_list.append([])
    mean_100_df.append([])
    ctr += 1 # Update counter after inner loop ends
    j += 100 # Update i to clip next 100 elements
# Out:
# j value is:  0
# j value is:  100
# j value is:  200
# j value is:  300
# j value is:  400
# j value is:  500
# j value is:  600
# j value is:  700
# j value is:  800
# j value is:  900
# j value is:  1000
# j value is:  1100
# j value is:  1200

# %% [markdown]
# # --> Creating a median_100_df with median for various features

# %%
len_max = 1235 # Since the max. number of rows for any company is 1235
median_list = [[]]
median_100_df = [[]]
ctr = 0
j = 0

while j < 1235:
    print("j value is: ", j)
    for company in my_df.index.get_level_values(0).unique():
        if len(my_df.loc[[company]]) < 1000:
            continue
            
        company_df = my_df.loc[company].iloc[j:j+100]
        median_table = company_df.median()
        d = {'Name': company}
        name_columns = ['bollinger_bandwidth','momentum_indic','pvi','rvi','st_dev','smi','stochastics','Will_R_Form','RSI','Aaron_Osc']
        for i in range(len(name_columns)):
            d[name_columns[i]] = median_table.loc[name_columns[i]]

        median_list[ctr].append(d)
    
    median_100_df[ctr] = pd.DataFrame(median_list[ctr])
    median_100_df[ctr].set_index('Name', inplace = True)
    
    median_list.append([])
    median_100_df.append([])
    ctr += 1 # Update counter after inner loop ends
    j += 100 # Update i to clip next 100 elements
# Out:
# j value is:  0
# j value is:  100
# j value is:  200
# j value is:  300
# j value is:  400
# j value is:  500
# j value is:  600
# j value is:  700
# j value is:  800
# j value is:  900
# j value is:  1000
# j value is:  1100
# j value is:  1200

# %%
try:
    if mean_100_df[-1] == []:
        mean_100_df.pop()
except: 
    None
    
try:
    if median_100_df[-1] == []:
        median_100_df.pop()
except: 
    None
    
try:
    if mean_year_df[-1] == []:
        mean_year_df.pop()
except: 
    None
    
try:
    if median_year_df[-1] == []:
        median_year_df.pop()
except: 
    None

# %% [markdown]
# # PCA

# %%
from mpl_toolkits import mplot3d
from sklearn.decomposition import PCA, KernelPCA
from sklearn.cluster import KMeans
    
for i in range(len(all_years)):
    
    pc_med = PCA(n_components = 3, svd_solver='full')
    x = pc_med.fit_transform(median_year_df[i])
    fig = plt.figure()
    ax = plt.axes(projection='3d')
    print("Variance explained: ", pc_med.explained_variance_ratio_*100.)

    plt.plot(x.T[0], x.T[1],x.T[2],'o')
    plt.title("Median of Features: YEAR " + all_years[i])
    plt.xlabel("PC 1")
    plt.ylabel("PC 2")
    ax.set_zlabel('PC 3')
    plt.show()

    pc_mean = PCA(n_components = 3, svd_solver='full')
    x = pc_mean.fit_transform(mean_year_df[i])
    fig = plt.figure()
    ax = plt.axes(projection='3d')
    print("Variance explained: ", pc_mean.explained_variance_ratio_*100.)

    plt.plot(x.T[0], x.T[1],x.T[2],'o')
    plt.title("Mean of Features: YEAR " + all_years[i])
    plt.xlabel("PC 1")
    plt.ylabel("PC 2")
    ax.set_zlabel("PC3")
    plt.show()
# Out:
# Variance explained:  [78.35293491 10.87289224  8.82661742]
# Variance explained:  [76.49935031 16.20979725  5.43353351]
# Variance explained:  [64.17192948 29.41804214  5.29159573]
# Variance explained:  [61.82190883 36.01385844  1.24537308]
# Variance explained:  [66.88089874 29.17830208  3.19227023]
# Variance explained:  [75.90039206 22.71747887  0.76946644]
# Variance explained:  [57.54528554 37.81737722  3.77682352]
# Variance explained:  [83.44905162 15.31806466  0.66986445]
# Variance explained:  [68.13090391 29.50347044  1.89151451]
# Variance explained:  [83.03101079 16.2963398   0.36741753]
# Variance explained:  [56.70811705 38.34787803  3.42105734]
# Variance explained:  [57.35941014 39.46738509  1.9815885 ]

# %% [markdown]
# # Kernel PCA

# %%
for i in range(len(all_years)):
    
    kernel_med = KernelPCA(kernel='poly', n_components = 3, degree=2)
    x = kernel_med.fit_transform(median_year_df[i])
    fig = plt.figure()
    ax = plt.axes(projection='3d')
    print("Variance explained: ", pc_med.explained_variance_ratio_*100.)

    plt.plot(x.T[0], x.T[1],x.T[2],'o')
    plt.title("Median of Features: YEAR " + all_years[i])
    plt.xlabel("PC 1")
    plt.ylabel("PC 2")
    ax.set_zlabel('PC 3')
    plt.show()

    kernel_mean = KernelPCA(kernel='poly', n_components = 3, degree=2)
    x = kernel_mean.fit_transform(mean_year_df[i])
    fig = plt.figure()
    ax = plt.axes(projection='3d')
    print("Variance explained: ", pc_mean.explained_variance_ratio_*100.)

    plt.plot(x.T[0], x.T[1],x.T[2],'o')
    plt.title("Mean of Features: YEAR " + all_years[i])
    plt.xlabel("PC 1")
    plt.ylabel("PC 2")
    ax.set_zlabel("PC3")
    plt.show()
# Out:
# Variance explained:  [56.70811705 38.34787803  3.42105734]
# Variance explained:  [57.35941014 39.46738509  1.9815885 ]
# Variance explained:  [56.70811705 38.34787803  3.42105734]
# Variance explained:  [57.35941014 39.46738509  1.9815885 ]
# Variance explained:  [56.70811705 38.34787803  3.42105734]
# Variance explained:  [57.35941014 39.46738509  1.9815885 ]
# Variance explained:  [56.70811705 38.34787803  3.42105734]
# Variance explained:  [57.35941014 39.46738509  1.9815885 ]
# Variance explained:  [56.70811705 38.34787803  3.42105734]
# Variance explained:  [57.35941014 39.46738509  1.9815885 ]
# Variance explained:  [56.70811705 38.34787803  3.42105734]
# Variance explained:  [57.35941014 39.46738509  1.9815885 ]

# %%
weblink = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
actual_cluster = pd.read_html(weblink)[0]
actual_cluster.set_index(['Symbol'], inplace = True)
actual_cluster.sort_index()
actual_sector = actual_cluster[['GICS Sector']]
accuracy = []

for i in range(len(mean_100_df)):
    mean_sector_df = pd.DataFrame.join(mean_100_df[i], actual_sector)

    from sklearn.model_selection import train_test_split

    mean_sector_df = mean_sector_df.dropna()
    x = mean_sector_df.iloc[:,:-1]
    y = mean_sector_df.iloc[:,-1]

    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0) 

    from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

    lda = LDA (n_components = 3)
    x_train = lda.fit_transform(x_train, y_train)
    accuracy.append([lda.score(x_test, y_test, sample_weight=None)])
    plt.plot(np.cumsum(np.array(lda.explained_variance_ratio_)), 'o--', label = i)
    
plt.xlabel('Number of components (features)')
plt.ylabel('Cumulative Variance Explained')
plt.title('LDA: Cumulative Variance v/s Number of Features')
plt.legend()
plt.show()

# %%
plt.plot(np.array(accuracy)*100, 'o--')
plt.title('Acuuracy v/s N-tile Samples')
plt.xlabel('N-tile Number (Each mean sample calculated using 100 time data points)')
plt.ylabel('Accuracy of prediction by LDA')
# Out:
# Text(0, 0.5, 'Accuracy of prediction by LDA')
